# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisandeepmedisetty/python-handson/blob/main/python_objects%26datastructure_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world");
# Out:
# hello world
